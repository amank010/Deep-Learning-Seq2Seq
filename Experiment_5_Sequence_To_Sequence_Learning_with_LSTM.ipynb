# %%
# Sequence-to-Sequence Learning with LSTM

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
from torch.nn.utils.rnn import pad_sequence
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction

# %%
# Check If CUDA is Available, Else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
modes = ["without_attention", "bahdanau", "luong"]

# %%
# Load Dataset
def load_data(path, limit = 10000):
    with open(path, "r", encoding = 'utf-8') as f:
        lines = [line.strip().split('\t') for line in f if '\t' in line]
    random.shuffle(lines)
    
    return lines[:limit]

# %%
# Build Vocabulary
def build_vocab(sentences):
    vocab = {'<pad>': 0, '<sos>': 1, '<eos>': 2, '<unk>': 3}
    counter = Counter(word for s in sentences for word in s.lower().split())
    for word in counter:
        vocab[word] = len(vocab)
        
    return vocab

# %%
# Tokenize Sentence
def tokenize(sentence, vocab):
    return [vocab.get(w, vocab['<unk>']) for w in sentence.lower().split()]

# %%
# Prepare Dataset
def prepare_dataset(pairs, src_vocab, tgt_vocab):
    X, Y = [], []
    for src, tgt in pairs:
        x = tokenize(src, src_vocab)
        y = [tgt_vocab['<sos>']] + tokenize(tgt, tgt_vocab) + [tgt_vocab['<eos>']]
        X.append(torch.tensor(x, dtype = torch.long))
        Y.append(torch.tensor(y, dtype = torch.long))
        
    return X, Y

# %%
# Pad Batch
def collate_fn(batch_x, batch_y):
    src = pad_sequence(batch_x, batch_first = True, padding_value = src_vocab['<pad>'])
    tgt = pad_sequence(batch_y, batch_first = True, padding_value = tgt_vocab['<pad>'])
    return src.to(device), tgt.to(device)

# %%
# Encoder
class Encoder(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, batch_first = True)
        
    def forward(self, x):
        x = self.embedding(x)
        outputs, (h, c) = self.lstm(x)
        
        return outputs, (h, c)

# %%
# Bahdanau Attention
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attn = nn.Linear(hidden_size * 2, hidden_size)
        self.v = nn.Parameter(torch.rand(hidden_size))
        
    def forward(self, hidden, encoder_outputs):
        hidden = hidden[-1].unsqueeze(1).repeat(1, encoder_outputs.size(1), 1)
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2)))
        score = torch.sum(self.v * energy, dim = 2)
        
        return torch.softmax(score, dim = 1)

# %%
# Luong Attention
class LuongAttention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attn = nn.Linear(hidden_size, hidden_size)
        
    def forward(self, hidden, encoder_outputs):
        hidden = hidden[-1].unsqueeze(2)
        energy = self.attn(encoder_outputs)
        score = torch.bmm(energy, hidden).squeeze(2)
        
        return torch.softmax(score, dim = 1)

# %%
# Decoder
class Decoder(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, mode):
        super().__init__()
        self.mode = mode
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.attn = BahdanauAttention(hidden_size) if mode == "bahdanau" else \
                    LuongAttention(hidden_size) if mode == "luong" else None
        self.lstm = nn.LSTM(embed_size + hidden_size if self.attn else embed_size, hidden_size, batch_first = True)
        self.fc = nn.Linear(hidden_size * 2 if self.attn else hidden_size, vocab_size)
        
    def forward(self, x, hidden, cell, encoder_outputs = None):
        x = self.embedding(x.unsqueeze(1))
        attn_weights = None
        if self.attn:
            attn_weights = self.attn(hidden, encoder_outputs)
            context = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)
            x = torch.cat((x, context), dim = 2)
        output, (hidden, cell) = self.lstm(x, (hidden, cell))
        if self.attn:
            output = torch.cat((output.squeeze(1), context.squeeze(1)), dim = 1)
        else:
            output = output.squeeze(1)
            
        return self.fc(output), hidden, cell, attn_weights

# %%
# Seq2Seq Model
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        
    def forward(self, src, tgt, teacher_forcing = 0.5):
        batch_size, tgt_len = tgt.shape
        vocab_size = self.decoder.fc.out_features
        outputs = torch.zeros(batch_size, tgt_len, vocab_size).to(device)
        enc_outputs, (h, c) = self.encoder(src)
        x = tgt[:, 0]
        for t in range(1, tgt_len):
            out, h, c, _ = self.decoder(x, h, c, enc_outputs if self.decoder.attn else None)
            outputs[:, t] = out
            x = tgt[:, t] if random.random() < teacher_forcing else out.argmax(1)
            
        return outputs

# %%
# Training the Model
# Training the Model
def train(model, xdata, ydata, val_data = None, epochs = 5):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
    criterion = nn.CrossEntropyLoss(ignore_index=tgt_vocab['<pad>'])
    for epoch in range(epochs):
        total_loss = 0
        for i in range(0, len(xdata), 64):
            src, tgt = collate_fn(xdata[i:i+64], ydata[i:i+64])
            output = model(src, tgt)
            loss = criterion(output[:, 1:].reshape(-1, output.shape[-1]), tgt[:, 1:].reshape(-1))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        if val_data:
            model.eval()
            val_x, val_y = val_data
            with torch.no_grad():
                src, tgt = collate_fn(val_x, val_y)
                output = model(src, tgt)
                val_loss = criterion(output[:, 1:].reshape(-1, output.shape[-1]), tgt[:, 1:].reshape(-1))
            print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}, Validation Loss: {val_loss.item():.4f}")
            model.train()
        else:
            print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")

# %%
# Translate
def translate(model, sentence):
    model.eval()
    tokens = tokenize(sentence, src_vocab)
    src = torch.tensor(tokens).unsqueeze(0).to(device)
    enc_outputs, (h, c) = model.encoder(src)
    x = torch.tensor([tgt_vocab['<sos>']]).to(device)
    result = []
    for _ in range(20):
        out, h, c, _ = model.decoder(x, h, c, enc_outputs if model.decoder.attn else None)
        x = out.argmax(1)
        word = tgt_ivocab[x.item()]
        if word == "<eos>":
            break
        result.append(word)
        
    return ' '.join(result)

# %%
# BLEU Evaluation
def evaluate_bleu(model):
    refs, preds = [], []
    for x, y in zip(X_test[:100], Y_test[:100]):
        src_sent = ' '.join([src_ivocab[t.item()] for t in x])
        tgt_sent = [tgt_ivocab[t.item()] for t in y[1:-1]]
        pred = translate(model, src_sent).split()
        refs.append([tgt_sent])
        preds.append(pred)
        
    smoothing = SmoothingFunction().method1
    return corpus_bleu(refs, preds, smoothing_function = smoothing)

# %%
# Attention Visualization
def visualize_attention(model, sentence):
    if MODE == "without_attention":
        print("No Attention to Visualize.")
        return
    model.eval()
    tokens = tokenize(sentence, src_vocab)
    src = torch.tensor(tokens).unsqueeze(0).to(device)
    enc_outputs, (h, c) = model.encoder(src)
    x = torch.tensor([tgt_vocab['<sos>']]).to(device)
    result = []
    attentions = []
    for _ in range(20):
        out, h, c, attn = model.decoder(x, h, c, enc_outputs)
        x = out.argmax(1)
        word = tgt_ivocab[x.item()]
        if word == "<eos>":
            break
        result.append(word)
        attentions.append(attn.squeeze(0).cpu().detach().numpy())
        
    src_words = [src_ivocab[i] for i in tokens]
    fig = plt.figure(figsize = (10, 6))
    ax = fig.add_subplot(111)
    cax = ax.matshow(np.stack(attentions), cmap = "viridis")
    ax.set_xticks(range(len(src_words)))
    ax.set_yticks(range(len(result)))
    ax.set_xticklabels(src_words, rotation = 45)
    ax.set_yticklabels(result)
    ax.set_xlabel("Input Words")
    ax.set_ylabel("Output Words")
    plt.colorbar(cax)
    plt.title(f"Attention ({MODE})")
    plt.show()

# %%
# Load and Prepare Data
pairs = load_data("/kaggle/input/english-to-spanish/spa.txt")

# %%
src_text = [pair[0] for pair in pairs]
tgt_text = [pair[1] for pair in pairs]
src_vocab = build_vocab(src_text)
tgt_vocab = build_vocab(tgt_text)
src_ivocab = {i: w for w, i in src_vocab.items()}
tgt_ivocab = {i: w for w, i in tgt_vocab.items()}

# %%
X, Y = prepare_dataset(pairs, src_vocab, tgt_vocab)

# %%
# 10% Split for Test
X_temp, X_test, Y_temp, Y_test = train_test_split(X, Y, test_size = 0.1)

# 10% Split for Validation
X_train, X_val, Y_train, Y_val = train_test_split(X_temp, Y_temp, test_size = 0.1111)

# %%
# Run all Modes
for MODE in modes:
    print(f"\nRunning Mode: {MODE.upper()}")
    
    encoder = Encoder(len(src_vocab), 256, 512).to(device)
    decoder = Decoder(len(tgt_vocab), 256, 512, MODE).to(device)
    model = Seq2Seq(encoder, decoder).to(device)
    
    train(model, X_train, Y_train, val_data = (X_val, Y_val), epochs = 200)

    print("Translate:", translate(model, "I am happy."))
    print("BLEU Score:", evaluate_bleu(model))
    
    if MODE != "without_attention":
        visualize_attention(model, "I am happy.")
    else:
        print("No Attention Visualization (without_attention Mode).")
# Out:
# Running Mode: WITHOUT_ATTENTION
# Epoch 1, Loss: 822.5107, Validation Loss: 6.3836
# Epoch 2, Loss: 737.6790, Validation Loss: 6.1903
# Epoch 3, Loss: 698.1954, Validation Loss: 6.0953
# Epoch 4, Loss: 653.7727, Validation Loss: 6.0396
# Epoch 5, Loss: 611.5232, Validation Loss: 5.8121
# Epoch 6, Loss: 567.8876, Validation Loss: 5.6847
# Epoch 7, Loss: 529.1491, Validation Loss: 5.8133
# Epoch 8, Loss: 487.5933, Validation Loss: 5.7557
# Epoch 9, Loss: 447.7969, Validation Loss: 5.6230
# Epoch 10, Loss: 411.7792, Validation Loss: 5.7528
# Epoch 11, Loss: 380.4255, Validation Loss: 5.7848
# Epoch 12, Loss: 344.7298, Validation Loss: 5.6580
# Epoch 13, Loss: 312.3373, Validation Loss: 5.6089
# Epoch 14, Loss: 276.5858, Validation Loss: 5.8167
# Epoch 15, Loss: 246.1038, Validation Loss: 5.8340
# Epoch 16, Loss: 216.2125, Validation Loss: 6.0470
# Epoch 17, Loss: 192.7931, Validation Loss: 6.1177
# Epoch 18, Loss: 169.9787, Validation Loss: 6.1894
# Epoch 19, Loss: 142.7798, Validation Loss: 6.2619
# Epoch 20, Loss: 121.3912, Validation Loss: 6.4010
# Epoch 21, Loss: 99.7213, Validation Loss: 6.0212
# Epoch 22, Loss: 82.4246, Validation Loss: 6.5255
# Epoch 23, Loss: 66.4475, Validation Loss: 6.1607
# Epoch 24, Loss: 54.3694, Validation Loss: 6.1043
# Epoch 25, Loss: 43.9978, Validation Loss: 6.1344
# Epoch 26, Loss: 34.9784, Validation Loss: 6.5158
# Epoch 27, Loss: 26.6942, Validation Loss: 6.1593
# Epoch 28, Loss: 20.7486, Validation Loss: 6.7220
# Epoch 29, Loss: 17.1671, Validation Loss: 6.3911
# Epoch 30, Loss: 14.0670, Validation Loss: 7.1333
# Epoch 31, Loss: 11.8785, Validation Loss: 6.3164
# Epoch 32, Loss: 10.1692, Validation Loss: 7.0509
# Epoch 33, Loss: 8.6517, Validation Loss: 6.2152
# Epoch 34, Loss: 7.9540, Validation Loss: 6.8248
# Epoch 35, Loss: 7.1862, Validation Loss: 7.0080
# Epoch 36, Loss: 6.3945, Validation Loss: 6.8639
# Epoch 37, Loss: 5.6730, Validation Loss: 7.3361
# Epoch 38, Loss: 5.2922, Validation Loss: 7.4902
# Epoch 39, Loss: 5.0835, Validation Loss: 7.0129
# Epoch 40, Loss: 5.0928, Validation Loss: 7.6054
# Epoch 41, Loss: 4.5973, Validation Loss: 7.3996
# Epoch 42, Loss: 4.7517, Validation Loss: 7.7618
# Epoch 43, Loss: 4.9830, Validation Loss: 7.1483
# Epoch 44, Loss: 4.5336, Validation Loss: 7.1943
# Epoch 45, Loss: 4.1979, Validation Loss: 7.0843
# Epoch 46, Loss: 4.6359, Validation Loss: 6.8946
# Epoch 47, Loss: 5.3721, Validation Loss: 6.7050
# Epoch 48, Loss: 5.7072, Validation Loss: 6.9653
# Epoch 49, Loss: 6.1001, Validation Loss: 7.6777
# Epoch 50, Loss: 6.1454, Validation Loss: 8.2101
# Epoch 51, Loss: 5.9876, Validation Loss: 7.3722
# Epoch 52, Loss: 6.1886, Validation Loss: 7.0342
# Epoch 53, Loss: 5.3956, Validation Loss: 7.1582
# Epoch 54, Loss: 5.1841, Validation Loss: 7.0970
# Epoch 55, Loss: 4.4725, Validation Loss: 7.9580
# Epoch 56, Loss: 3.7845, Validation Loss: 7.2043
# Epoch 57, Loss: 3.8981, Validation Loss: 8.4450
# Epoch 58, Loss: 3.5671, Validation Loss: 8.0145
# Epoch 59, Loss: 3.1889, Validation Loss: 7.2123
# Epoch 60, Loss: 3.0955, Validation Loss: 7.9193
# Epoch 61, Loss: 2.9423, Validation Loss: 8.1111
# Epoch 62, Loss: 2.4914, Validation Loss: 7.7752
# Epoch 63, Loss: 2.1430, Validation Loss: 7.2494
# Epoch 64, Loss: 2.1558, Validation Loss: 8.4258
# Epoch 65, Loss: 2.1136, Validation Loss: 7.3387
# Epoch 66, Loss: 1.9580, Validation Loss: 7.6901
# Epoch 67, Loss: 1.8214, Validation Loss: 7.5581
# Epoch 68, Loss: 1.7773, Validation Loss: 7.1827
# Epoch 69, Loss: 1.8749, Validation Loss: 7.3462
# Epoch 70, Loss: 1.8096, Validation Loss: 8.0201
# Epoch 71, Loss: 1.8486, Validation Loss: 7.8182
# Epoch 72, Loss: 1.7317, Validation Loss: 8.0013
# Epoch 73, Loss: 1.7778, Validation Loss: 7.2267
# Epoch 74, Loss: 1.9832, Validation Loss: 8.1494
# Epoch 75, Loss: 1.6709, Validation Loss: 8.4387
# Epoch 76, Loss: 1.6507, Validation Loss: 7.4437
# Epoch 77, Loss: 1.7315, Validation Loss: 7.7024
# Epoch 78, Loss: 1.7945, Validation Loss: 7.1436
# Epoch 79, Loss: 3.1857, Validation Loss: 7.8731
# Epoch 80, Loss: 46.5173, Validation Loss: 7.6897
# Epoch 81, Loss: 37.7486, Validation Loss: 7.4659
# Epoch 82, Loss: 11.2364, Validation Loss: 8.0097
# Epoch 83, Loss: 4.0530, Validation Loss: 7.6598
# Epoch 84, Loss: 2.0237, Validation Loss: 7.5029
# Epoch 85, Loss: 1.7084, Validation Loss: 8.1559
# Epoch 86, Loss: 1.4208, Validation Loss: 8.0230
# Epoch 87, Loss: 1.4637, Validation Loss: 7.8394
# Epoch 88, Loss: 1.2777, Validation Loss: 7.8234
# Epoch 89, Loss: 1.3557, Validation Loss: 7.7317
# Epoch 90, Loss: 1.1907, Validation Loss: 7.6785
# Epoch 91, Loss: 1.2902, Validation Loss: 7.8373
# Epoch 92, Loss: 1.2523, Validation Loss: 8.3677
# Epoch 93, Loss: 1.3389, Validation Loss: 7.5891
# Epoch 94, Loss: 1.3983, Validation Loss: 7.9283
# Epoch 95, Loss: 1.2962, Validation Loss: 7.7867
# Epoch 96, Loss: 1.1685, Validation Loss: 8.5719
# Epoch 97, Loss: 1.2435, Validation Loss: 7.8144
# Epoch 98, Loss: 1.2296, Validation Loss: 7.6691
# Epoch 99, Loss: 1.2651, Validation Loss: 7.6728
# Epoch 100, Loss: 1.1498, Validation Loss: 7.6883
# Epoch 101, Loss: 1.3157, Validation Loss: 8.1228
# Epoch 102, Loss: 1.3929, Validation Loss: 7.4559
# Epoch 103, Loss: 1.1582, Validation Loss: 7.8517
# Epoch 104, Loss: 1.0925, Validation Loss: 7.9784
# Epoch 105, Loss: 1.0633, Validation Loss: 7.7980
# Epoch 106, Loss: 1.0448, Validation Loss: 8.4212
# Epoch 107, Loss: 1.1666, Validation Loss: 7.4711
# Epoch 108, Loss: 1.0731, Validation Loss: 8.5978
# Epoch 109, Loss: 1.0358, Validation Loss: 7.7549
# Epoch 110, Loss: 1.1284, Validation Loss: 8.2310
# Epoch 111, Loss: 1.2022, Validation Loss: 8.1161
# Epoch 112, Loss: 1.1115, Validation Loss: 8.2544
# Epoch 113, Loss: 1.0603, Validation Loss: 7.6312
# Epoch 114, Loss: 1.3785, Validation Loss: 8.3003
# Epoch 115, Loss: 1.0996, Validation Loss: 7.9606
# Epoch 116, Loss: 1.1600, Validation Loss: 7.7560
# Epoch 117, Loss: 1.4082, Validation Loss: 8.1860
# Epoch 118, Loss: 2.0621, Validation Loss: 7.5369
# Epoch 119, Loss: 21.2989, Validation Loss: 7.6692
# Epoch 120, Loss: 37.6453, Validation Loss: 7.7382
# Epoch 121, Loss: 14.2423, Validation Loss: 7.8171
# Epoch 122, Loss: 3.8341, Validation Loss: 7.3923
# Epoch 123, Loss: 2.0967, Validation Loss: 7.9566
# Epoch 124, Loss: 1.5956, Validation Loss: 7.9142
# Epoch 125, Loss: 1.1536, Validation Loss: 8.1579
# Epoch 126, Loss: 0.9851, Validation Loss: 7.8984
# Epoch 127, Loss: 1.1999, Validation Loss: 7.6657
# Epoch 128, Loss: 1.0947, Validation Loss: 8.0458
# Epoch 129, Loss: 1.0246, Validation Loss: 8.3203
# Epoch 130, Loss: 0.9226, Validation Loss: 8.3320
# Epoch 131, Loss: 1.0159, Validation Loss: 8.4472
# Epoch 132, Loss: 1.0152, Validation Loss: 7.8193
# Epoch 133, Loss: 1.0083, Validation Loss: 7.9480
# Epoch 134, Loss: 0.8591, Validation Loss: 8.1088
# Epoch 135, Loss: 0.8128, Validation Loss: 8.1214
# Epoch 136, Loss: 0.8735, Validation Loss: 7.8385
# Epoch 137, Loss: 0.8147, Validation Loss: 8.3801
# Epoch 138, Loss: 0.8838, Validation Loss: 7.7803
# Epoch 139, Loss: 0.8357, Validation Loss: 8.5727
# Epoch 140, Loss: 0.9748, Validation Loss: 8.1957
# Epoch 141, Loss: 1.0355, Validation Loss: 7.8732
# Epoch 142, Loss: 0.9750, Validation Loss: 8.6033
# Epoch 143, Loss: 0.9805, Validation Loss: 8.2238
# Epoch 144, Loss: 0.9471, Validation Loss: 8.2507
# Epoch 145, Loss: 0.9359, Validation Loss: 7.9972
# Epoch 146, Loss: 1.1037, Validation Loss: 8.3477
# Epoch 147, Loss: 1.2184, Validation Loss: 8.2871
# Epoch 148, Loss: 1.1709, Validation Loss: 8.5666
# Epoch 149, Loss: 1.7303, Validation Loss: 8.8806
# Epoch 150, Loss: 1.3729, Validation Loss: 8.4528
# Epoch 151, Loss: 1.2469, Validation Loss: 8.5520
# Epoch 152, Loss: 1.1444, Validation Loss: 7.8483
# Epoch 153, Loss: 1.1870, Validation Loss: 9.1694
# Epoch 154, Loss: 1.2016, Validation Loss: 8.1657
# Epoch 155, Loss: 1.0293, Validation Loss: 8.1218
# Epoch 156, Loss: 1.2675, Validation Loss: 8.3556
# Epoch 157, Loss: 4.3463, Validation Loss: 8.4393
# Epoch 158, Loss: 19.5873, Validation Loss: 7.9520
# Epoch 159, Loss: 16.6637, Validation Loss: 7.5643
# Epoch 160, Loss: 5.7044, Validation Loss: 7.6256
# Epoch 161, Loss: 2.1983, Validation Loss: 7.8756
# Epoch 162, Loss: 1.3493, Validation Loss: 8.6355
# Epoch 163, Loss: 1.0471, Validation Loss: 8.4213
# Epoch 164, Loss: 0.9320, Validation Loss: 8.0993
# Epoch 165, Loss: 0.7314, Validation Loss: 8.2523
# Epoch 166, Loss: 0.7561, Validation Loss: 8.5237
# Epoch 167, Loss: 0.7458, Validation Loss: 7.6656
# Epoch 168, Loss: 0.7924, Validation Loss: 8.7988
# Epoch 169, Loss: 0.8441, Validation Loss: 7.9323
# Epoch 170, Loss: 0.7278, Validation Loss: 8.4132
# Epoch 171, Loss: 0.7422, Validation Loss: 9.0507
# Epoch 172, Loss: 0.8280, Validation Loss: 8.4628
# Epoch 173, Loss: 0.8153, Validation Loss: 8.7772
# Epoch 174, Loss: 0.7257, Validation Loss: 7.8798
# Epoch 175, Loss: 0.7394, Validation Loss: 7.9429
# Epoch 176, Loss: 0.8322, Validation Loss: 7.9108
# Epoch 177, Loss: 0.7138, Validation Loss: 9.8336
# Epoch 178, Loss: 0.7909, Validation Loss: 7.8274
# Epoch 179, Loss: 0.8925, Validation Loss: 8.7774
# Epoch 180, Loss: 0.8373, Validation Loss: 8.2051
# Epoch 181, Loss: 0.8795, Validation Loss: 8.9922
# Epoch 182, Loss: 1.0729, Validation Loss: 7.9457
# Epoch 183, Loss: 0.9232, Validation Loss: 8.1664
# Epoch 184, Loss: 0.9670, Validation Loss: 7.9579
# Epoch 185, Loss: 0.7646, Validation Loss: 8.3516
# Epoch 186, Loss: 0.8196, Validation Loss: 8.6004
# Epoch 187, Loss: 0.5962, Validation Loss: 8.7433
# Epoch 188, Loss: 0.6685, Validation Loss: 9.2609
# Epoch 189, Loss: 0.7141, Validation Loss: 9.5443
# Epoch 190, Loss: 0.7710, Validation Loss: 9.0475
# Epoch 191, Loss: 0.6506, Validation Loss: 8.6152
# Epoch 192, Loss: 0.6798, Validation Loss: 8.2280
# Epoch 193, Loss: 0.6828, Validation Loss: 7.7824
# Epoch 194, Loss: 0.5505, Validation Loss: 9.3049
# Epoch 195, Loss: 0.7418, Validation Loss: 8.6095
# Epoch 196, Loss: 0.6732, Validation Loss: 7.9891
# Epoch 197, Loss: 0.7689, Validation Loss: 8.8960
# Epoch 198, Loss: 0.8766, Validation Loss: 9.7600
# Epoch 199, Loss: 0.7914, Validation Loss: 9.2915
# Epoch 200, Loss: 2.5623, Validation Loss: 9.2474
# Translate: soy feliz.
# BLEU Score: 0.028006512830471748
# No Attention Visualization (without_attention Mode).
#
# Running Mode: BAHDANAU
# Epoch 1, Loss: 804.5364, Validation Loss: 6.0209
# Epoch 2, Loss: 650.9303, Validation Loss: 5.6364
# Epoch 3, Loss: 537.5033, Validation Loss: 5.4203
# Epoch 4, Loss: 428.9790, Validation Loss: 5.3237
# Epoch 5, Loss: 330.1283, Validation Loss: 5.4843
# Epoch 6, Loss: 256.2400, Validation Loss: 5.4112
# Epoch 7, Loss: 203.5229, Validation Loss: 5.3406
# Epoch 8, Loss: 169.8324, Validation Loss: 5.4113
# Epoch 9, Loss: 143.7733, Validation Loss: 5.5564
# Epoch 10, Loss: 116.0991, Validation Loss: 5.6426
# Epoch 11, Loss: 95.5544, Validation Loss: 5.3104
# Epoch 12, Loss: 76.8354, Validation Loss: 5.4271
# Epoch 13, Loss: 59.9713, Validation Loss: 5.5460
# Epoch 14, Loss: 47.7507, Validation Loss: 5.6579
# Epoch 15, Loss: 38.6057, Validation Loss: 5.8561
# Epoch 16, Loss: 31.4917, Validation Loss: 5.6364
# Epoch 17, Loss: 25.5114, Validation Loss: 5.6731
# Epoch 18, Loss: 22.4445, Validation Loss: 6.0188
# Epoch 19, Loss: 20.1663, Validation Loss: 5.6628
# Epoch 20, Loss: 17.2315, Validation Loss: 5.8172
# Epoch 21, Loss: 15.0301, Validation Loss: 6.1124
# Epoch 22, Loss: 11.9899, Validation Loss: 5.9194
# Epoch 23, Loss: 10.1081, Validation Loss: 5.5698
# Epoch 24, Loss: 9.2791, Validation Loss: 5.8994
# Epoch 25, Loss: 8.0300, Validation Loss: 6.2755
# Epoch 26, Loss: 6.9031, Validation Loss: 5.9279
# Epoch 27, Loss: 6.3848, Validation Loss: 6.1068
# Epoch 28, Loss: 5.7569, Validation Loss: 5.7548
# Epoch 29, Loss: 5.8033, Validation Loss: 6.3897
# Epoch 30, Loss: 5.8176, Validation Loss: 5.9606
# Epoch 31, Loss: 5.8381, Validation Loss: 6.1611
# Epoch 32, Loss: 6.6445, Validation Loss: 5.9550
# Epoch 33, Loss: 8.5627, Validation Loss: 5.9771
# Epoch 34, Loss: 10.5032, Validation Loss: 5.8004
# Epoch 35, Loss: 11.7872, Validation Loss: 6.0962
# Epoch 36, Loss: 13.8098, Validation Loss: 6.1633
# Epoch 37, Loss: 15.9835, Validation Loss: 6.5462
# Epoch 38, Loss: 17.0596, Validation Loss: 6.3189
# Epoch 39, Loss: 17.2431, Validation Loss: 6.3754
# Epoch 40, Loss: 13.8752, Validation Loss: 6.8181
# Epoch 41, Loss: 10.4355, Validation Loss: 5.8707
# Epoch 42, Loss: 7.4939, Validation Loss: 6.4340
# Epoch 43, Loss: 5.3560, Validation Loss: 6.3729
# Epoch 44, Loss: 4.7245, Validation Loss: 6.6063
# Epoch 45, Loss: 3.6479, Validation Loss: 5.8939
# Epoch 46, Loss: 3.2774, Validation Loss: 7.0092
# Epoch 47, Loss: 2.9713, Validation Loss: 6.1606
# Epoch 48, Loss: 2.7900, Validation Loss: 7.4037
# Epoch 49, Loss: 2.8264, Validation Loss: 6.5824
# Epoch 50, Loss: 2.7268, Validation Loss: 6.4080
# Epoch 51, Loss: 2.5626, Validation Loss: 6.3273
# Epoch 52, Loss: 2.5116, Validation Loss: 7.0434
# Epoch 53, Loss: 2.5237, Validation Loss: 6.4533
# Epoch 54, Loss: 2.7507, Validation Loss: 6.4529
# Epoch 55, Loss: 2.7806, Validation Loss: 6.5229
# Epoch 56, Loss: 2.4306, Validation Loss: 6.8662
# Epoch 57, Loss: 2.4601, Validation Loss: 5.9556
# Epoch 58, Loss: 2.5621, Validation Loss: 6.3931
# Epoch 59, Loss: 2.5414, Validation Loss: 6.8551
# Epoch 60, Loss: 2.6094, Validation Loss: 6.6138
# Epoch 61, Loss: 3.7021, Validation Loss: 7.5497
# Epoch 62, Loss: 23.0745, Validation Loss: 6.0841
# Epoch 63, Loss: 53.9174, Validation Loss: 6.5110
# Epoch 64, Loss: 43.5788, Validation Loss: 6.7203
# Epoch 65, Loss: 22.4585, Validation Loss: 5.8010
# Epoch 66, Loss: 9.6704, Validation Loss: 6.3925
# Epoch 67, Loss: 5.3238, Validation Loss: 6.2689
# Epoch 68, Loss: 3.1537, Validation Loss: 6.2978
# Epoch 69, Loss: 2.4096, Validation Loss: 6.4042
# Epoch 70, Loss: 2.1152, Validation Loss: 6.9208
# Epoch 71, Loss: 1.8589, Validation Loss: 6.9957
# Epoch 72, Loss: 1.8603, Validation Loss: 6.3151
# Epoch 73, Loss: 1.8707, Validation Loss: 6.5920
# Epoch 74, Loss: 1.7065, Validation Loss: 6.5438
# Epoch 75, Loss: 1.6738, Validation Loss: 6.4131
# Epoch 76, Loss: 1.6689, Validation Loss: 6.5008
# Epoch 77, Loss: 1.8095, Validation Loss: 6.7814
# Epoch 78, Loss: 1.7816, Validation Loss: 7.5114
# Epoch 79, Loss: 1.8214, Validation Loss: 6.7268
# Epoch 80, Loss: 1.6193, Validation Loss: 6.6478
# Epoch 81, Loss: 1.8963, Validation Loss: 6.3485
# Epoch 82, Loss: 1.7037, Validation Loss: 6.5332
# Epoch 83, Loss: 1.7512, Validation Loss: 6.5777
# Epoch 84, Loss: 1.8212, Validation Loss: 6.7592
# Epoch 85, Loss: 1.8797, Validation Loss: 7.6432
# Epoch 86, Loss: 1.7891, Validation Loss: 6.5915
# Epoch 87, Loss: 1.8895, Validation Loss: 6.4659
# Epoch 88, Loss: 1.8004, Validation Loss: 6.9861
# Epoch 89, Loss: 1.8273, Validation Loss: 6.4134
# Epoch 90, Loss: 3.2034, Validation Loss: 6.2001
# Epoch 91, Loss: 14.4734, Validation Loss: 6.5852
# Epoch 92, Loss: 29.8261, Validation Loss: 7.1883
# Epoch 93, Loss: 27.2879, Validation Loss: 6.6265
# Epoch 94, Loss: 15.8203, Validation Loss: 6.7472
# Epoch 95, Loss: 7.5563, Validation Loss: 7.0852
# Epoch 96, Loss: 3.7464, Validation Loss: 7.3313
# Epoch 97, Loss: 2.3700, Validation Loss: 6.0531
# Epoch 98, Loss: 1.7516, Validation Loss: 6.8810
# Epoch 99, Loss: 1.4976, Validation Loss: 7.1096
# Epoch 100, Loss: 1.3458, Validation Loss: 6.1284
# Epoch 101, Loss: 1.4394, Validation Loss: 6.5985
# Epoch 102, Loss: 1.1972, Validation Loss: 7.1422
# Epoch 103, Loss: 1.2478, Validation Loss: 6.2804
# Epoch 104, Loss: 1.1619, Validation Loss: 7.3787
# Epoch 105, Loss: 1.1309, Validation Loss: 6.3534
# Epoch 106, Loss: 1.1647, Validation Loss: 6.9483
# Epoch 107, Loss: 1.1750, Validation Loss: 6.5255
# Epoch 108, Loss: 1.1889, Validation Loss: 6.8598
# Epoch 109, Loss: 1.0418, Validation Loss: 7.2920
# Epoch 110, Loss: 1.2693, Validation Loss: 7.2064
# Epoch 111, Loss: 1.1942, Validation Loss: 6.6824
# Epoch 112, Loss: 1.2406, Validation Loss: 7.0330
# Epoch 113, Loss: 1.4105, Validation Loss: 7.4785
# Epoch 114, Loss: 1.4595, Validation Loss: 7.6957
# Epoch 115, Loss: 1.5832, Validation Loss: 6.6792
# Epoch 116, Loss: 1.6599, Validation Loss: 7.8864
# Epoch 117, Loss: 1.6511, Validation Loss: 7.4482
# Epoch 118, Loss: 1.8133, Validation Loss: 7.4331
# Epoch 119, Loss: 2.4388, Validation Loss: 7.9960
# Epoch 120, Loss: 5.1884, Validation Loss: 7.3713
# Epoch 121, Loss: 16.9853, Validation Loss: 6.8003
# Epoch 122, Loss: 22.9028, Validation Loss: 6.8119
# Epoch 123, Loss: 16.4674, Validation Loss: 6.3229
# Epoch 124, Loss: 7.5361, Validation Loss: 7.1838
# Epoch 125, Loss: 3.8268, Validation Loss: 6.6877
# Epoch 126, Loss: 2.0812, Validation Loss: 7.9545
# Epoch 127, Loss: 1.4024, Validation Loss: 7.2846
# Epoch 128, Loss: 1.1425, Validation Loss: 6.6662
# Epoch 129, Loss: 1.0036, Validation Loss: 6.3183
# Epoch 130, Loss: 1.0301, Validation Loss: 6.9312
# Epoch 131, Loss: 0.9705, Validation Loss: 7.0323
# Epoch 132, Loss: 0.9183, Validation Loss: 6.5509
# Epoch 133, Loss: 0.9903, Validation Loss: 7.4262
# Epoch 134, Loss: 1.0331, Validation Loss: 6.9124
# Epoch 135, Loss: 0.9281, Validation Loss: 7.2363
# Epoch 136, Loss: 1.0908, Validation Loss: 7.2008
# Epoch 137, Loss: 0.9911, Validation Loss: 6.4411
# Epoch 138, Loss: 0.9112, Validation Loss: 7.5740
# Epoch 139, Loss: 0.9608, Validation Loss: 6.7126
# Epoch 140, Loss: 0.8678, Validation Loss: 7.5777
# Epoch 141, Loss: 0.9540, Validation Loss: 7.0825
# Epoch 142, Loss: 1.0233, Validation Loss: 7.0483
# Epoch 143, Loss: 0.9185, Validation Loss: 7.9072
# Epoch 144, Loss: 1.0351, Validation Loss: 7.4103
# Epoch 145, Loss: 0.9183, Validation Loss: 7.0500
# Epoch 146, Loss: 0.9902, Validation Loss: 8.0032
# Epoch 147, Loss: 1.1281, Validation Loss: 7.2013
# Epoch 148, Loss: 1.1946, Validation Loss: 6.7848
# Epoch 149, Loss: 1.6416, Validation Loss: 7.4031
# Epoch 150, Loss: 2.9670, Validation Loss: 6.9549
# Epoch 151, Loss: 11.9423, Validation Loss: 6.7100
# Epoch 152, Loss: 21.0220, Validation Loss: 7.5533
# Epoch 153, Loss: 16.6845, Validation Loss: 6.9218
# Epoch 154, Loss: 7.7376, Validation Loss: 6.7084
# Epoch 155, Loss: 4.0855, Validation Loss: 7.8840
# Epoch 156, Loss: 2.1482, Validation Loss: 7.0098
# Epoch 157, Loss: 1.2968, Validation Loss: 7.1142
# Epoch 158, Loss: 0.9390, Validation Loss: 7.3234
# Epoch 159, Loss: 0.8073, Validation Loss: 6.9469
# Epoch 160, Loss: 0.8637, Validation Loss: 7.0887
# Epoch 161, Loss: 0.7590, Validation Loss: 6.8049
# Epoch 162, Loss: 0.7131, Validation Loss: 8.1002
# Epoch 163, Loss: 0.8322, Validation Loss: 7.6161
# Epoch 164, Loss: 0.7199, Validation Loss: 6.9022
# Epoch 165, Loss: 0.7489, Validation Loss: 7.1440
# Epoch 166, Loss: 0.7849, Validation Loss: 7.6339
# Epoch 167, Loss: 0.7155, Validation Loss: 7.4079
# Epoch 168, Loss: 0.7500, Validation Loss: 6.5086
# Epoch 169, Loss: 0.8106, Validation Loss: 7.8179
# Epoch 170, Loss: 0.6803, Validation Loss: 7.1493
# Epoch 171, Loss: 0.7912, Validation Loss: 7.1075
# Epoch 172, Loss: 0.6864, Validation Loss: 7.3864
# Epoch 173, Loss: 0.7489, Validation Loss: 6.9142
# Epoch 174, Loss: 0.6578, Validation Loss: 7.4302
# Epoch 175, Loss: 0.7082, Validation Loss: 6.8762
# Epoch 176, Loss: 0.7441, Validation Loss: 7.2638
# Epoch 177, Loss: 0.6716, Validation Loss: 6.9788
# Epoch 178, Loss: 0.6663, Validation Loss: 6.9331
# Epoch 179, Loss: 0.8083, Validation Loss: 7.4019
# Epoch 180, Loss: 1.2265, Validation Loss: 6.6441
# Epoch 181, Loss: 1.3658, Validation Loss: 7.0619
# Epoch 182, Loss: 1.2301, Validation Loss: 7.6619
# Epoch 183, Loss: 1.9114, Validation Loss: 7.2937
# Epoch 184, Loss: 5.0890, Validation Loss: 6.7905
# Epoch 185, Loss: 14.4885, Validation Loss: 6.7711
# Epoch 186, Loss: 17.4124, Validation Loss: 7.1001
# Epoch 187, Loss: 9.7343, Validation Loss: 7.7234
# Epoch 188, Loss: 3.7965, Validation Loss: 7.2497
# Epoch 189, Loss: 1.7989, Validation Loss: 7.8690
# Epoch 190, Loss: 0.9359, Validation Loss: 7.9377
# Epoch 191, Loss: 0.7846, Validation Loss: 7.1237
# Epoch 192, Loss: 0.8227, Validation Loss: 6.9132
# Epoch 193, Loss: 0.6806, Validation Loss: 7.2859
# Epoch 194, Loss: 0.5836, Validation Loss: 7.2930
# Epoch 195, Loss: 0.5469, Validation Loss: 8.0252
# Epoch 196, Loss: 0.6321, Validation Loss: 7.6558
# Epoch 197, Loss: 0.6173, Validation Loss: 7.6604
# Epoch 198, Loss: 0.6707, Validation Loss: 7.1505
# Epoch 199, Loss: 0.6156, Validation Loss: 7.3575
# Epoch 200, Loss: 0.6038, Validation Loss: 7.8913
# Translate: yo estoy feliz.
# BLEU Score: 0.033397153764017085
# Running Mode: LUONG
# Epoch 1, Loss: 806.2103, Validation Loss: 5.9302
# Epoch 2, Loss: 663.5737, Validation Loss: 5.5763
# Epoch 3, Loss: 562.0512, Validation Loss: 5.4633
# Epoch 4, Loss: 462.7519, Validation Loss: 5.2301
# Epoch 5, Loss: 370.6600, Validation Loss: 5.2908
# Epoch 6, Loss: 291.8681, Validation Loss: 5.1756
# Epoch 7, Loss: 241.3490, Validation Loss: 5.2379
# Epoch 8, Loss: 197.9924, Validation Loss: 5.3238
# Epoch 9, Loss: 168.1555, Validation Loss: 5.2132
# Epoch 10, Loss: 145.1157, Validation Loss: 5.2971
# Epoch 11, Loss: 124.3286, Validation Loss: 5.4227
# Epoch 12, Loss: 100.0165, Validation Loss: 5.2511
# Epoch 13, Loss: 87.5815, Validation Loss: 5.2776
# Epoch 14, Loss: 74.1513, Validation Loss: 5.0971
# Epoch 15, Loss: 62.6781, Validation Loss: 5.5479
# Epoch 16, Loss: 52.8830, Validation Loss: 5.4224
# Epoch 17, Loss: 46.2077, Validation Loss: 5.4449
# Epoch 18, Loss: 41.1808, Validation Loss: 5.4822
# Epoch 19, Loss: 35.2117, Validation Loss: 5.5311
# Epoch 20, Loss: 29.6741, Validation Loss: 5.4195
# Epoch 21, Loss: 27.0739, Validation Loss: 6.0094
# Epoch 22, Loss: 22.8516, Validation Loss: 5.6991
# Epoch 23, Loss: 17.8297, Validation Loss: 5.6881
# Epoch 24, Loss: 15.0707, Validation Loss: 5.5895
# Epoch 25, Loss: 13.6053, Validation Loss: 5.6235
# Epoch 26, Loss: 13.2766, Validation Loss: 5.9778
# Epoch 27, Loss: 12.7028, Validation Loss: 6.3980
# Epoch 28, Loss: 13.8795, Validation Loss: 5.7745
# Epoch 29, Loss: 12.6381, Validation Loss: 6.2432
# Epoch 30, Loss: 16.8283, Validation Loss: 6.0433
# Epoch 31, Loss: 16.9661, Validation Loss: 5.8596
# Epoch 32, Loss: 15.9434, Validation Loss: 6.0980
# Epoch 33, Loss: 12.4612, Validation Loss: 6.1010
# Epoch 34, Loss: 12.0977, Validation Loss: 6.0904
# Epoch 35, Loss: 9.7782, Validation Loss: 6.5683
# Epoch 36, Loss: 9.6154, Validation Loss: 5.9000
# Epoch 37, Loss: 9.4290, Validation Loss: 6.5218
# Epoch 38, Loss: 9.7491, Validation Loss: 6.3111
# Epoch 39, Loss: 10.3569, Validation Loss: 6.2760
# Epoch 40, Loss: 7.9888, Validation Loss: 6.2327
# Epoch 41, Loss: 6.3279, Validation Loss: 6.3458
# Epoch 42, Loss: 6.8244, Validation Loss: 6.7200
# Epoch 43, Loss: 6.8783, Validation Loss: 6.7233
# Epoch 44, Loss: 6.9987, Validation Loss: 6.5317
# Epoch 45, Loss: 7.4381, Validation Loss: 6.7201
# Epoch 46, Loss: 6.3025, Validation Loss: 7.3201
# Epoch 47, Loss: 8.7228, Validation Loss: 6.4088
# Epoch 48, Loss: 7.7675, Validation Loss: 5.9029
# Epoch 49, Loss: 9.4778, Validation Loss: 6.1185
# Epoch 50, Loss: 11.2003, Validation Loss: 6.3042
# Epoch 51, Loss: 9.6165, Validation Loss: 6.3392
# Epoch 52, Loss: 9.0753, Validation Loss: 6.3646
# Epoch 53, Loss: 8.8457, Validation Loss: 6.3484
# Epoch 54, Loss: 7.1656, Validation Loss: 6.4743
# Epoch 55, Loss: 5.9597, Validation Loss: 6.4944
# Epoch 56, Loss: 5.1728, Validation Loss: 6.8245
# Epoch 57, Loss: 5.6950, Validation Loss: 6.9725
# Epoch 58, Loss: 6.9569, Validation Loss: 6.7158
# Epoch 59, Loss: 8.9408, Validation Loss: 7.0721
# Epoch 60, Loss: 10.7256, Validation Loss: 6.2984
# Epoch 61, Loss: 12.0384, Validation Loss: 6.2854
# Epoch 62, Loss: 11.9470, Validation Loss: 7.1748
# Epoch 63, Loss: 11.5136, Validation Loss: 6.6675
# Epoch 64, Loss: 10.8444, Validation Loss: 6.6999
# Epoch 65, Loss: 9.2051, Validation Loss: 6.3685
# Epoch 66, Loss: 6.1065, Validation Loss: 6.7483
# Epoch 67, Loss: 4.2932, Validation Loss: 7.6399
# Epoch 68, Loss: 3.5287, Validation Loss: 6.5663
# Epoch 69, Loss: 3.0086, Validation Loss: 7.2361
# Epoch 70, Loss: 2.5482, Validation Loss: 6.7305
# Epoch 71, Loss: 2.7315, Validation Loss: 6.9183
# Epoch 72, Loss: 4.4347, Validation Loss: 6.2460
# Epoch 73, Loss: 7.8230, Validation Loss: 6.7656
# Epoch 74, Loss: 11.9186, Validation Loss: 7.5612
# Epoch 75, Loss: 10.8474, Validation Loss: 6.9895
# Epoch 76, Loss: 10.2835, Validation Loss: 6.9456
# Epoch 77, Loss: 8.2963, Validation Loss: 7.2763
# Epoch 78, Loss: 6.7304, Validation Loss: 6.8052
# Epoch 79, Loss: 7.1768, Validation Loss: 7.0423
# Epoch 80, Loss: 4.8592, Validation Loss: 6.7146
# Epoch 81, Loss: 3.2193, Validation Loss: 6.9225
# Epoch 82, Loss: 2.6404, Validation Loss: 6.3158
# Epoch 83, Loss: 2.6252, Validation Loss: 7.3031
# Epoch 84, Loss: 2.2160, Validation Loss: 6.9370
# Epoch 85, Loss: 2.2921, Validation Loss: 7.8427
# Epoch 86, Loss: 1.9710, Validation Loss: 6.6388
# Epoch 87, Loss: 2.0368, Validation Loss: 6.9240
# Epoch 88, Loss: 2.1119, Validation Loss: 7.0238
# Epoch 89, Loss: 1.8618, Validation Loss: 6.4172
# Epoch 90, Loss: 1.7416, Validation Loss: 7.0997
# Epoch 91, Loss: 1.9529, Validation Loss: 6.7911
# Epoch 92, Loss: 1.9326, Validation Loss: 6.8310
# Epoch 93, Loss: 1.9503, Validation Loss: 6.7468
# Epoch 94, Loss: 1.9732, Validation Loss: 6.9380
# Epoch 95, Loss: 1.9276, Validation Loss: 6.5950
# Epoch 96, Loss: 2.4823, Validation Loss: 6.5669
# Epoch 97, Loss: 7.7230, Validation Loss: 6.7391
# Epoch 98, Loss: 18.2658, Validation Loss: 6.8756
# Epoch 99, Loss: 32.3846, Validation Loss: 7.2961
# Epoch 100, Loss: 31.1143, Validation Loss: 6.5632
# Epoch 101, Loss: 16.3644, Validation Loss: 7.6362
# Epoch 102, Loss: 7.0461, Validation Loss: 7.4321
# Epoch 103, Loss: 4.4758, Validation Loss: 7.2763
# Epoch 104, Loss: 3.6122, Validation Loss: 7.3227
# Epoch 105, Loss: 3.0416, Validation Loss: 7.3363
# Epoch 106, Loss: 2.4445, Validation Loss: 6.5352
# Epoch 107, Loss: 1.9660, Validation Loss: 7.1308
# Epoch 108, Loss: 2.0392, Validation Loss: 6.7141
# Epoch 109, Loss: 1.9443, Validation Loss: 7.0443
# Epoch 110, Loss: 1.5910, Validation Loss: 7.0641
# Epoch 111, Loss: 1.7338, Validation Loss: 6.9425
# Epoch 112, Loss: 1.7083, Validation Loss: 7.1053
# Epoch 113, Loss: 1.7313, Validation Loss: 7.6352
# Epoch 114, Loss: 1.5585, Validation Loss: 7.3102
# Epoch 115, Loss: 1.6761, Validation Loss: 7.1121
# Epoch 116, Loss: 1.5241, Validation Loss: 7.3881
# Epoch 117, Loss: 1.5585, Validation Loss: 6.4595
# Epoch 118, Loss: 1.6238, Validation Loss: 6.7162
# Epoch 119, Loss: 1.6692, Validation Loss: 6.9212
# Epoch 120, Loss: 1.6484, Validation Loss: 6.7902
# Epoch 121, Loss: 1.7410, Validation Loss: 7.0479
# Epoch 122, Loss: 1.6740, Validation Loss: 7.5086
# Epoch 123, Loss: 1.5893, Validation Loss: 7.0736
# Epoch 124, Loss: 1.6542, Validation Loss: 7.1681
# Epoch 125, Loss: 1.6436, Validation Loss: 7.3864
# Epoch 126, Loss: 1.4958, Validation Loss: 6.5575
# Epoch 127, Loss: 2.9195, Validation Loss: 7.4771
# Epoch 128, Loss: 15.1327, Validation Loss: 7.5571
# Epoch 129, Loss: 30.1789, Validation Loss: 7.9539
# Epoch 130, Loss: 27.8799, Validation Loss: 6.8899
# Epoch 131, Loss: 14.8365, Validation Loss: 6.6205
# Epoch 132, Loss: 6.4373, Validation Loss: 6.6004
# Epoch 133, Loss: 3.6925, Validation Loss: 7.0136
# Epoch 134, Loss: 3.4253, Validation Loss: 7.1245
# Epoch 135, Loss: 3.4036, Validation Loss: 7.0902
# Epoch 136, Loss: 3.0707, Validation Loss: 7.3064
# Epoch 137, Loss: 2.2265, Validation Loss: 7.1551
# Epoch 138, Loss: 1.9637, Validation Loss: 6.7074
# Epoch 139, Loss: 1.7610, Validation Loss: 7.2228
# Epoch 140, Loss: 1.6644, Validation Loss: 7.1965
# Epoch 141, Loss: 1.6661, Validation Loss: 7.4677
# Epoch 142, Loss: 1.5802, Validation Loss: 7.3985
# Epoch 143, Loss: 1.4084, Validation Loss: 6.9627
# Epoch 144, Loss: 1.5662, Validation Loss: 7.6076
# Epoch 145, Loss: 1.4449, Validation Loss: 7.4323
# Epoch 146, Loss: 1.6077, Validation Loss: 7.2057
# Epoch 147, Loss: 1.4183, Validation Loss: 7.0147
# Epoch 148, Loss: 1.4817, Validation Loss: 7.4266
# Epoch 149, Loss: 1.3924, Validation Loss: 7.7559
# Epoch 150, Loss: 1.5077, Validation Loss: 6.7331
# Epoch 151, Loss: 3.0051, Validation Loss: 7.2977
# Epoch 152, Loss: 10.9267, Validation Loss: 6.8925
# Epoch 153, Loss: 17.6617, Validation Loss: 6.9941
# Epoch 154, Loss: 14.6240, Validation Loss: 6.8009
# Epoch 155, Loss: 9.2363, Validation Loss: 7.2682
# Epoch 156, Loss: 5.5708, Validation Loss: 7.4827
# Epoch 157, Loss: 4.0924, Validation Loss: 7.1190
# Epoch 158, Loss: 2.9502, Validation Loss: 7.1463
# Epoch 159, Loss: 2.0420, Validation Loss: 7.2124
# Epoch 160, Loss: 1.7477, Validation Loss: 6.5661
# Epoch 161, Loss: 1.4408, Validation Loss: 6.7096
# Epoch 162, Loss: 1.4101, Validation Loss: 8.1580
# Epoch 163, Loss: 1.4721, Validation Loss: 7.4198
# Epoch 164, Loss: 1.3976, Validation Loss: 7.0471
# Epoch 165, Loss: 1.3889, Validation Loss: 6.8894
# Epoch 166, Loss: 1.2955, Validation Loss: 7.5739
# Epoch 167, Loss: 1.1878, Validation Loss: 7.5374
# Epoch 168, Loss: 1.2745, Validation Loss: 8.3794
# Epoch 169, Loss: 1.3279, Validation Loss: 8.3528
# Epoch 170, Loss: 1.5586, Validation Loss: 6.8381
# Epoch 171, Loss: 1.5394, Validation Loss: 8.0754
# Epoch 172, Loss: 1.5938, Validation Loss: 7.6245
# Epoch 173, Loss: 1.4350, Validation Loss: 7.5158
# Epoch 174, Loss: 1.5413, Validation Loss: 7.3657
# Epoch 175, Loss: 1.4743, Validation Loss: 7.7351
# Epoch 176, Loss: 1.5211, Validation Loss: 7.5400
# Epoch 177, Loss: 1.8162, Validation Loss: 6.9942
# Epoch 178, Loss: 4.3327, Validation Loss: 7.0009
# Epoch 179, Loss: 14.6285, Validation Loss: 7.2474
# Epoch 180, Loss: 18.2562, Validation Loss: 6.8096
# Epoch 181, Loss: 12.7229, Validation Loss: 7.3990
# Epoch 182, Loss: 8.1224, Validation Loss: 7.3283
# Epoch 183, Loss: 5.5313, Validation Loss: 7.5652
# Epoch 184, Loss: 3.3746, Validation Loss: 6.9359
# Epoch 185, Loss: 2.3572, Validation Loss: 7.6944
# Epoch 186, Loss: 1.6085, Validation Loss: 7.2695
# Epoch 187, Loss: 1.4915, Validation Loss: 7.6700
# Epoch 188, Loss: 1.5393, Validation Loss: 7.2803
# Epoch 189, Loss: 1.5217, Validation Loss: 7.5841
# Epoch 190, Loss: 1.2373, Validation Loss: 7.7044
# Epoch 191, Loss: 1.1591, Validation Loss: 7.0231
# Epoch 192, Loss: 1.0479, Validation Loss: 7.1420
# Epoch 193, Loss: 1.1806, Validation Loss: 7.2073
# Epoch 194, Loss: 0.9937, Validation Loss: 7.7399
# Epoch 195, Loss: 1.1905, Validation Loss: 6.8165
# Epoch 196, Loss: 1.0277, Validation Loss: 7.7353
# Epoch 197, Loss: 1.0935, Validation Loss: 7.0341
# Epoch 198, Loss: 1.1751, Validation Loss: 7.5615
# Epoch 199, Loss: 0.9698, Validation Loss: 7.0440
# Epoch 200, Loss: 0.9963, Validation Loss: 7.1885
# Translate: soy bueno feliz.
# BLEU Score: 0.04331289550939456
